# %% [markdown]
# # First Steps with the OANDA API

# %% [markdown]
# ## Connecting to the API / Server

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
api.get_account_summary()
# Out:
# {'id': '101-011-29824769-001',
#  'alias': 'Primary',
#  'currency': 'AUD',
#  'balance': '99993.7785',
#  'createdByUserID': 29824769,
#  'createdTime': '2024-09-02T22:42:48.601781899Z',
#  'guaranteedStopLossOrderMode': 'ALLOWED',
#  'pl': '-6.2215',
#  'resettablePL': '-6.2215',
#  'resettablePLTime': '0',
#  'financing': '0.0',
#  'commission': '0.0',
#  'guaranteedExecutionFees': '0.0',
#  'marginRate': '0.02',
#  'openTradeCount': 0,
#  'openPositionCount': 0,
#  'pendingOrderCount': 0,
#  'hedgingEnabled': False,
#  'unrealizedPL': '0.0',
#  'NAV': '99993.7785',
#  'marginUsed': '0.0',
#  'marginAvailable': '99993.7785',
#  'positionValue': '0.0',
#  'marginCloseoutUnrealizedPL': '0.0',
#  'marginCloseoutNAV': '99993.7785',
#  'marginCloseoutMarginUsed': '0.0',
#  'marginCloseoutPercent': '0.0',
#  'marginCloseoutPositionValue': '0.0',
#  'withdrawalLimit': '99993.7785',
#  'marginCallMarginUsed': '0.0',
#  'marginCallPercent': '0.0',
#  'lastTransactionID': '9'}

# %%
api.account_type
# Out:
# 'practice'

# %%
api.stream_hostname
# Out:
# 'stream-fxpractice.oanda.com'

# %%
api.account_id
# Out:
# '101-011-29824769-001'

# %%
api.get_instruments()
# Out:
# [('AUD/CAD', 'AUD_CAD'),
#  ('AUD/CHF', 'AUD_CHF'),
#  ('AUD/HKD', 'AUD_HKD'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('AUD/NZD', 'AUD_NZD'),
#  ('AUD/SGD', 'AUD_SGD'),
#  ('AUD/USD', 'AUD_USD'),
#  ('Australia 200', 'AU200_AUD'),
#  ('Bitcoin', 'BTC_USD'),
#  ('Bitcoin Cash', 'BCH_USD'),
#  ('Brent Crude Oil', 'BCO_USD'),
#  ('Bund', 'DE10YB_EUR'),
#  ('CAD/CHF', 'CAD_CHF'),
#  ('CAD/HKD', 'CAD_HKD'),
#  ('CAD/JPY', 'CAD_JPY'),
#  ('CAD/SGD', 'CAD_SGD'),
#  ('CHF/HKD', 'CHF_HKD'),
#  ('CHF/JPY', 'CHF_JPY'),
#  ('CHF/ZAR', 'CHF_ZAR'),
#  ('China A50', 'CN50_USD'),
#  ('China H Shares', 'CHINAH_HKD'),
#  ('Copper', 'XCU_USD'),
#  ('Corn', 'CORN_USD'),
#  ('EUR/AUD', 'EUR_AUD'),
#  ('EUR/CAD', 'EUR_CAD'),
#  ('EUR/CHF', 'EUR_CHF'),
#  ('EUR/CZK', 'EUR_CZK'),
#  ('EUR/DKK', 'EUR_DKK'),
#  ('EUR/GBP', 'EUR_GBP'),
#  ('EUR/HKD', 'EUR_HKD'),
#  ('EUR/HUF', 'EUR_HUF'),
#  ('EUR/JPY', 'EUR_JPY'),
#  ('EUR/NOK', 'EUR_NOK'),
#  ('EUR/NZD', 'EUR_NZD'),
#  ('EUR/PLN', 'EUR_PLN'),
#  ('EUR/SEK', 'EUR_SEK'),
#  ('EUR/SGD', 'EUR_SGD'),
#  ('EUR/TRY', 'EUR_TRY'),
#  ('EUR/USD', 'EUR_USD'),
#  ('EUR/ZAR', 'EUR_ZAR'),
#  ('Ether', 'ETH_USD'),
#  ('Europe 50', 'EU50_EUR'),
#  ('France 40', 'FR40_EUR'),
#  ('GBP/AUD', 'GBP_AUD'),
#  ('GBP/CAD', 'GBP_CAD'),
#  ('GBP/CHF', 'GBP_CHF'),
#  ('GBP/HKD', 'GBP_HKD'),
#  ('GBP/JPY', 'GBP_JPY'),
#  ('GBP/NZD', 'GBP_NZD'),
#  ('GBP/PLN', 'GBP_PLN'),
#  ('GBP/SGD', 'GBP_SGD'),
#  ('GBP/USD', 'GBP_USD'),
#  ('GBP/ZAR', 'GBP_ZAR'),
#  ('Germany 30', 'DE30_EUR'),
#  ('Gold', 'XAU_USD'),
#  ('Gold/AUD', 'XAU_AUD'),
#  ('Gold/CAD', 'XAU_CAD'),
#  ('Gold/CHF', 'XAU_CHF'),
#  ('Gold/EUR', 'XAU_EUR'),
#  ('Gold/GBP', 'XAU_GBP'),
#  ('Gold/HKD', 'XAU_HKD'),
#  ('Gold/JPY', 'XAU_JPY'),
#  ('Gold/NZD', 'XAU_NZD'),
#  ('Gold/SGD', 'XAU_SGD'),
#  ('Gold/Silver', 'XAU_XAG'),
#  ('HKD/JPY', 'HKD_JPY'),
#  ('Hong Kong 33', 'HK33_HKD'),
#  ('Japan 225', 'JP225_USD'),
#  ('Japan 225 (JPY)', 'JP225Y_JPY'),
#  ('Litecoin', 'LTC_USD'),
#  ('NZD/CAD', 'NZD_CAD'),
#  ('NZD/CHF', 'NZD_CHF'),
#  ('NZD/HKD', 'NZD_HKD'),
#  ('NZD/JPY', 'NZD_JPY'),
#  ('NZD/SGD', 'NZD_SGD'),
#  ('NZD/USD', 'NZD_USD'),
#  ('Natural Gas', 'NATGAS_USD'),
#  ('Netherlands 25', 'NL25_EUR'),
#  ('Palladium', 'XPD_USD'),
#  ('Platinum', 'XPT_USD'),
#  ('SGD/CHF', 'SGD_CHF'),
#  ('SGD/JPY', 'SGD_JPY'),
#  ('Silver', 'XAG_USD'),
#  ('Silver/AUD', 'XAG_AUD'),
#  ('Silver/CAD', 'XAG_CAD'),
#  ('Silver/CHF', 'XAG_CHF'),
#  ('Silver/EUR', 'XAG_EUR'),
#  ('Silver/GBP', 'XAG_GBP'),
#  ('Silver/HKD', 'XAG_HKD'),
#  ('Silver/JPY', 'XAG_JPY'),
#  ('Silver/NZD', 'XAG_NZD'),
#  ('Silver/SGD', 'XAG_SGD'),
#  ('Singapore 30', 'SG30_SGD'),
#  ('Soybeans', 'SOYBN_USD'),
#  ('Spain 35', 'ESPIX_EUR'),
#  ('Sugar', 'SUGAR_USD'),
#  ('Switzerland 20', 'CH20_CHF'),
#  ('TRY/JPY', 'TRY_JPY'),
#  ('UK 100', 'UK100_GBP'),
#  ('UK 10Y Gilt', 'UK10YB_GBP'),
#  ('US 10Y T-Note', 'USB10Y_USD'),
#  ('US 2Y T-Note', 'USB02Y_USD'),
#  ('US 5Y T-Note', 'USB05Y_USD'),
#  ('US Nas 100', 'NAS100_USD'),
#  ('US Russ 2000', 'US2000_USD'),
#  ('US SPX 500', 'SPX500_USD'),
#  ('US T-Bond', 'USB30Y_USD'),
#  ('US Wall St 30', 'US30_USD'),
#  ('USD/CAD', 'USD_CAD'),
#  ('USD/CHF', 'USD_CHF'),
#  ('USD/CNH', 'USD_CNH'),
#  ('USD/CZK', 'USD_CZK'),
#  ('USD/DKK', 'USD_DKK'),
#  ('USD/HKD', 'USD_HKD'),
#  ('USD/HUF', 'USD_HUF'),
#  ('USD/JPY', 'USD_JPY'),
#  ('USD/MXN', 'USD_MXN'),
#  ('USD/NOK', 'USD_NOK'),
#  ('USD/PLN', 'USD_PLN'),
#  ('USD/SEK', 'USD_SEK'),
#  ('USD/SGD', 'USD_SGD'),
#  ('USD/THB', 'USD_THB'),
#  ('USD/TRY', 'USD_TRY'),
#  ('USD/ZAR', 'USD_ZAR'),
#  ('West Texas Oil', 'WTICO_USD'),
#  ('Wheat', 'WHEAT_USD'),
#  ('ZAR/JPY', 'ZAR_JPY')]

# %%
instr = api.get_instruments()

# %%
len(instr)
# Out:
# 127

# %%
instr[0]
# Out:
# ('AUD/CAD', 'AUD_CAD')

# %% [markdown]
# ## Getting Historical Data (Part 1)

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
help(api.get_history)
# Out:
# Help on method get_history in module tpqoa.tpqoa:
#
# get_history(instrument, start, end, granularity, price, localize=True) method of tpqoa.tpqoa.tpqoa instance
#     Retrieves historical data for instrument.
#
#     Parameters
#     ==========
#     instrument: string
#         valid instrument name
#     start, end: datetime, str
#         Python datetime or string objects for start and end
#     granularity: string
#         a string like 'S5', 'M1' or 'D'
#     price: string
#         one of 'A' (ask), 'B' (bid) or 'M' (middle)
#
#     Returns
#     =======
#     data: pd.DataFrame
#         pandas DataFrame object with data

# %%
api.get_history(instrument = "EUR_USD", start = "2020-07-01", end = "2020-07-31",
                granularity = "D", price = "B")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2020-06-30 21:00:00  1.12293  1.12744  1.11837  1.12501   90252      True
# 2020-07-01 21:00:00  1.12501  1.13020  1.12188  1.12384   90789      True
# 2020-07-02 21:00:00  1.12384  1.12492  1.12186  1.12429   59036      True
# 2020-07-05 21:00:00  1.12423  1.13449  1.12391  1.13076   81756      True
# 2020-07-06 21:00:00  1.13070  1.13318  1.12581  1.12726   92426      True
# 2020-07-07 21:00:00  1.12717  1.13505  1.12615  1.13287   89549      True
# 2020-07-08 21:00:00  1.13287  1.13699  1.12774  1.12837  104729      True
# 2020-07-09 21:00:00  1.12808  1.13242  1.12540  1.12977   81510      True
# 2020-07-12 21:00:00  1.13042  1.13744  1.13002  1.13420   86512      True
# 2020-07-13 21:00:00  1.13420  1.14081  1.13232  1.13985  106478      True
# 2020-07-14 21:00:00  1.13979  1.14512  1.13901  1.14108  100308      True
# 2020-07-15 21:00:00  1.14108  1.14411  1.13698  1.13827  102144      True
# 2020-07-16 21:00:00  1.13827  1.14432  1.13737  1.14252   73024      True
# 2020-07-19 21:00:00  1.14088  1.14672  1.14017  1.14461  104209      True
# 2020-07-20 21:00:00  1.14461  1.15391  1.14223  1.15257  111043      True
# 2020-07-21 21:00:00  1.15257  1.16009  1.15059  1.15687  129890      True
# 2020-07-22 21:00:00  1.15634  1.16260  1.15397  1.15952  115345      True
# 2020-07-23 21:00:00  1.15920  1.16571  1.15806  1.16540  115447      True
# 2020-07-26 21:00:00  1.16420  1.17809  1.16387  1.17502  123653      True
# 2020-07-27 21:00:00  1.17502  1.17729  1.16980  1.17138  126006      True
# 2020-07-28 21:00:00  1.17145  1.18054  1.17114  1.17904  121087      True
# 2020-07-29 21:00:00  1.17904  1.18475  1.17304  1.18465  128163      True
# 2020-07-30 21:00:00  1.18465  1.19081  1.17602  1.17751  154943      True

# %%
df = api.get_history(instrument = "EUR_USD", start = "2020-07-01", end = "2020-07-31",
                granularity = "D", price = "B")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23 entries, 2020-06-30 21:00:00 to 2020-07-30 21:00:00
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   o         23 non-null     float64
#  1   h         23 non-null     float64
#  2   l         23 non-null     float64
#  3   c         23 non-null     float64
#  4   volume    23 non-null     int64
#  5   complete  23 non-null     bool
# dtypes: bool(1), float64(4), int64(1)
# memory usage: 1.1 KB

# %%
api.get_history(instrument = "EUR_USD", start = "2020-07-01", end = "2020-07-01",
                granularity = "D", price = "A")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2020-06-30 21:00:00  1.12393  1.12758  1.11858  1.12527   90252      True

# %%
api.get_history(instrument = "EUR_USD", start = "2020-07-01", end = "2020-07-01",
                granularity = "D", price = "B")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2020-06-30 21:00:00  1.12293  1.12744  1.11837  1.12501   90252      True

# %% [markdown]
# ## Getting Historical Data (Part 2)
# Getting data from oanda with shorter timeframes <BR>
# `api.get_history("Symbol", "start_date", "end_date", "Timeframe", "price_type")` e.g
# <br>
# ```
# api.get_history('EUR_USD', '2020-08-03' '2020-08-05', 'H1', 'A')
# ```

# %%
api.get_history("EUR_USD", "2020-08-03", "2020-08-05", "H1", "A")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2020-08-03 00:00:00  1.17821  1.17900  1.17418  1.17543    6315      True
# 2020-08-03 01:00:00  1.17544  1.17732  1.17461  1.17722    4786      True
# 2020-08-03 02:00:00  1.17720  1.17744  1.17638  1.17691    2092      True
# 2020-08-03 03:00:00  1.17693  1.17768  1.17672  1.17741    1561      True
# 2020-08-03 04:00:00  1.17739  1.17832  1.17722  1.17770    1496      True
# 2020-08-03 05:00:00  1.17767  1.17799  1.17678  1.17746    1959      True
# 2020-08-03 06:00:00  1.17748  1.17762  1.17495  1.17508    5793      True
# 2020-08-03 07:00:00  1.17510  1.17687  1.17506  1.17631    9003      True
# 2020-08-03 08:00:00  1.17632  1.17857  1.17601  1.17798    8002      True
# 2020-08-03 09:00:00  1.17799  1.17804  1.17430  1.17452    6627      True
# 2020-08-03 10:00:00  1.17451  1.17460  1.17149  1.17257    7682      True
# 2020-08-03 11:00:00  1.17258  1.17354  1.17254  1.17260    5557      True
# 2020-08-03 12:00:00  1.17259  1.17350  1.17068  1.17083    7233      True
# 2020-08-03 13:00:00  1.17084  1.17250  1.16966  1.17241    9396      True
# 2020-08-03 14:00:00  1.17240  1.17441  1.17224  1.17388   11324      True
# 2020-08-03 15:00:00  1.17388  1.17514  1.17342  1.17504    6837      True
# 2020-08-03 16:00:00  1.17503  1.17528  1.17390  1.17499    3956      True
# 2020-08-03 17:00:00  1.17498  1.17593  1.17477  1.17526    3572      True
# 2020-08-03 18:00:00  1.17526  1.17642  1.17516  1.17598    3120      True
# 2020-08-03 19:00:00  1.17596  1.17666  1.17587  1.17649    2793      True
# 2020-08-03 20:00:00  1.17648  1.17687  1.17630  1.17632    1166      True
# 2020-08-03 21:00:00  1.17632  1.17699  1.17618  1.17639     175      True
# 2020-08-03 22:00:00  1.17629  1.17693  1.17603  1.17613     416      True
# 2020-08-03 23:00:00  1.17615  1.17618  1.17569  1.17611     559      True
# 2020-08-04 00:00:00  1.17609  1.17624  1.17529  1.17545    1472      True
# 2020-08-04 01:00:00  1.17546  1.17602  1.17540  1.17592    1610      True
# 2020-08-04 02:00:00  1.17590  1.17741  1.17577  1.17730    1475      True
# 2020-08-04 03:00:00  1.17729  1.17748  1.17642  1.17686    1386      True
# 2020-08-04 04:00:00  1.17687  1.17754  1.17678  1.17747    1169      True
# 2020-08-04 05:00:00  1.17746  1.17781  1.17648  1.17675    1617      True
# 2020-08-04 06:00:00  1.17677  1.17809  1.17649  1.17777    5409      True
# 2020-08-04 07:00:00  1.17780  1.18034  1.17725  1.17874   11029      True
# 2020-08-04 08:00:00  1.17872  1.17959  1.17736  1.17936    9091      True
# 2020-08-04 09:00:00  1.17933  1.18071  1.17928  1.17955    7353      True
# 2020-08-04 10:00:00  1.17955  1.17961  1.17687  1.17708    7140      True
# 2020-08-04 11:00:00  1.17709  1.17741  1.17553  1.17620    7599      True
# 2020-08-04 12:00:00  1.17618  1.17719  1.17229  1.17290   10370      True
# 2020-08-04 13:00:00  1.17291  1.17389  1.17221  1.17254   10603      True
# 2020-08-04 14:00:00  1.17256  1.17652  1.17249  1.17573   11371      True
# 2020-08-04 15:00:00  1.17574  1.17744  1.17514  1.17659    7072      True
# 2020-08-04 16:00:00  1.17658  1.17785  1.17653  1.17785    5020      True
# 2020-08-04 17:00:00  1.17784  1.17860  1.17767  1.17835    3868      True
# 2020-08-04 18:00:00  1.17834  1.17924  1.17753  1.17830    3394      True
# 2020-08-04 19:00:00  1.17828  1.18038  1.17827  1.18033    3615      True
# 2020-08-04 20:00:00  1.18037  1.18043  1.17953  1.18040    1088      True
# 2020-08-04 21:00:00  1.18063  1.18063  1.17984  1.17989      53      True
# 2020-08-04 22:00:00  1.17984  1.18013  1.17937  1.17990     675      True
# 2020-08-04 23:00:00  1.17992  1.18161  1.17954  1.18148     897      True

# %%
api.get_history("EUR_USD", "2020-08-03", "2020-08-05", "H12", "A")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2020-08-02 21:00:00  1.17828  1.17976  1.17418  1.17798   43624      True
# 2020-08-03 09:00:00  1.17799  1.17804  1.16966  1.17632   69263      True
# 2020-08-03 21:00:00  1.17632  1.18034  1.17529  1.17936   35408      True
# 2020-08-04 09:00:00  1.17933  1.18071  1.17221  1.18040   78493      True
# 2020-08-04 21:00:00  1.18063  1.18421  1.17937  1.18408   33438      True

# %%
api.get_history("EUR_USD", "2020-08-03", "2020-08-05", "M1", "A")
# Out:
#                            o        h        l        c  volume  complete
# time
# 2020-08-03 00:00:00  1.17821  1.17835  1.17819  1.17835      44      True
# 2020-08-03 00:01:00  1.17835  1.17871  1.17833  1.17871      59      True
# 2020-08-03 00:02:00  1.17873  1.17896  1.17873  1.17884      62      True
# 2020-08-03 00:03:00  1.17885  1.17900  1.17877  1.17877      36      True
# 2020-08-03 00:04:00  1.17877  1.17877  1.17824  1.17835      64      True
# ...                      ...      ...      ...      ...     ...       ...
# 2020-08-04 23:55:00  1.18098  1.18161  1.18096  1.18147     129      True
# 2020-08-04 23:56:00  1.18149  1.18161  1.18146  1.18159      28      True
# 2020-08-04 23:57:00  1.18156  1.18160  1.18152  1.18156      23      True
# 2020-08-04 23:58:00  1.18154  1.18161  1.18148  1.18155      15      True
# 2020-08-04 23:59:00  1.18153  1.18155  1.18147  1.18148      11      True
#
# [2803 rows x 6 columns]

# %%
api.get_history("EUR_USD", "2020-08-03", "2020-08-04", "S5", "A")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\tpqoa-0.0.56-py3.12.egg\tpqoa\tpqoa.py:223: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#                            o        h        l        c  volume  complete
# time
# 2020-08-03 00:00:00  1.17821  1.17830  1.17819  1.17828      16      True
# 2020-08-03 00:00:10  1.17827  1.17832  1.17824  1.17832       6      True
# 2020-08-03 00:00:15  1.17830  1.17830  1.17823  1.17826       7      True
# 2020-08-03 00:00:30  1.17829  1.17830  1.17828  1.17829       4      True
# 2020-08-03 00:00:35  1.17827  1.17827  1.17827  1.17827       1      True
# ...                      ...      ...      ...      ...     ...       ...
# 2020-08-03 23:57:50  1.17609  1.17613  1.17609  1.17613       3      True
# 2020-08-03 23:58:35  1.17613  1.17613  1.17613  1.17613       1      True
# 2020-08-03 23:59:45  1.17613  1.17613  1.17611  1.17611       2      True
# 2020-08-03 23:59:50  1.17609  1.17611  1.17609  1.17611       2      True
# 2020-08-04 00:00:00  1.17609  1.17609  1.17608  1.17608       2      True
#
# [13562 rows x 6 columns]

# %%
api.get_instruments()
# Out:
# [('AUD/CAD', 'AUD_CAD'),
#  ('AUD/CHF', 'AUD_CHF'),
#  ('AUD/HKD', 'AUD_HKD'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('AUD/NZD', 'AUD_NZD'),
#  ('AUD/SGD', 'AUD_SGD'),
#  ('AUD/USD', 'AUD_USD'),
#  ('Australia 200', 'AU200_AUD'),
#  ('Bitcoin', 'BTC_USD'),
#  ('Bitcoin Cash', 'BCH_USD'),
#  ('Brent Crude Oil', 'BCO_USD'),
#  ('Bund', 'DE10YB_EUR'),
#  ('CAD/CHF', 'CAD_CHF'),
#  ('CAD/HKD', 'CAD_HKD'),
#  ('CAD/JPY', 'CAD_JPY'),
#  ('CAD/SGD', 'CAD_SGD'),
#  ('CHF/HKD', 'CHF_HKD'),
#  ('CHF/JPY', 'CHF_JPY'),
#  ('CHF/ZAR', 'CHF_ZAR'),
#  ('China A50', 'CN50_USD'),
#  ('China H Shares', 'CHINAH_HKD'),
#  ('Copper', 'XCU_USD'),
#  ('Corn', 'CORN_USD'),
#  ('EUR/AUD', 'EUR_AUD'),
#  ('EUR/CAD', 'EUR_CAD'),
#  ('EUR/CHF', 'EUR_CHF'),
#  ('EUR/CZK', 'EUR_CZK'),
#  ('EUR/DKK', 'EUR_DKK'),
#  ('EUR/GBP', 'EUR_GBP'),
#  ('EUR/HKD', 'EUR_HKD'),
#  ('EUR/HUF', 'EUR_HUF'),
#  ('EUR/JPY', 'EUR_JPY'),
#  ('EUR/NOK', 'EUR_NOK'),
#  ('EUR/NZD', 'EUR_NZD'),
#  ('EUR/PLN', 'EUR_PLN'),
#  ('EUR/SEK', 'EUR_SEK'),
#  ('EUR/SGD', 'EUR_SGD'),
#  ('EUR/TRY', 'EUR_TRY'),
#  ('EUR/USD', 'EUR_USD'),
#  ('EUR/ZAR', 'EUR_ZAR'),
#  ('Ether', 'ETH_USD'),
#  ('Europe 50', 'EU50_EUR'),
#  ('France 40', 'FR40_EUR'),
#  ('GBP/AUD', 'GBP_AUD'),
#  ('GBP/CAD', 'GBP_CAD'),
#  ('GBP/CHF', 'GBP_CHF'),
#  ('GBP/HKD', 'GBP_HKD'),
#  ('GBP/JPY', 'GBP_JPY'),
#  ('GBP/NZD', 'GBP_NZD'),
#  ('GBP/PLN', 'GBP_PLN'),
#  ('GBP/SGD', 'GBP_SGD'),
#  ('GBP/USD', 'GBP_USD'),
#  ('GBP/ZAR', 'GBP_ZAR'),
#  ('Germany 30', 'DE30_EUR'),
#  ('Gold', 'XAU_USD'),
#  ('Gold/AUD', 'XAU_AUD'),
#  ('Gold/CAD', 'XAU_CAD'),
#  ('Gold/CHF', 'XAU_CHF'),
#  ('Gold/EUR', 'XAU_EUR'),
#  ('Gold/GBP', 'XAU_GBP'),
#  ('Gold/HKD', 'XAU_HKD'),
#  ('Gold/JPY', 'XAU_JPY'),
#  ('Gold/NZD', 'XAU_NZD'),
#  ('Gold/SGD', 'XAU_SGD'),
#  ('Gold/Silver', 'XAU_XAG'),
#  ('HKD/JPY', 'HKD_JPY'),
#  ('Hong Kong 33', 'HK33_HKD'),
#  ('Japan 225', 'JP225_USD'),
#  ('Japan 225 (JPY)', 'JP225Y_JPY'),
#  ('Litecoin', 'LTC_USD'),
#  ('NZD/CAD', 'NZD_CAD'),
#  ('NZD/CHF', 'NZD_CHF'),
#  ('NZD/HKD', 'NZD_HKD'),
#  ('NZD/JPY', 'NZD_JPY'),
#  ('NZD/SGD', 'NZD_SGD'),
#  ('NZD/USD', 'NZD_USD'),
#  ('Natural Gas', 'NATGAS_USD'),
#  ('Netherlands 25', 'NL25_EUR'),
#  ('Palladium', 'XPD_USD'),
#  ('Platinum', 'XPT_USD'),
#  ('SGD/CHF', 'SGD_CHF'),
#  ('SGD/JPY', 'SGD_JPY'),
#  ('Silver', 'XAG_USD'),
#  ('Silver/AUD', 'XAG_AUD'),
#  ('Silver/CAD', 'XAG_CAD'),
#  ('Silver/CHF', 'XAG_CHF'),
#  ('Silver/EUR', 'XAG_EUR'),
#  ('Silver/GBP', 'XAG_GBP'),
#  ('Silver/HKD', 'XAG_HKD'),
#  ('Silver/JPY', 'XAG_JPY'),
#  ('Silver/NZD', 'XAG_NZD'),
#  ('Silver/SGD', 'XAG_SGD'),
#  ('Singapore 30', 'SG30_SGD'),
#  ('Soybeans', 'SOYBN_USD'),
#  ('Spain 35', 'ESPIX_EUR'),
#  ('Sugar', 'SUGAR_USD'),
#  ('Switzerland 20', 'CH20_CHF'),
#  ('TRY/JPY', 'TRY_JPY'),
#  ('UK 100', 'UK100_GBP'),
#  ('UK 10Y Gilt', 'UK10YB_GBP'),
#  ('US 10Y T-Note', 'USB10Y_USD'),
#  ('US 2Y T-Note', 'USB02Y_USD'),
#  ('US 5Y T-Note', 'USB05Y_USD'),
#  ('US Nas 100', 'NAS100_USD'),
#  ('US Russ 2000', 'US2000_USD'),
#  ('US SPX 500', 'SPX500_USD'),
#  ('US T-Bond', 'USB30Y_USD'),
#  ('US Wall St 30', 'US30_USD'),
#  ('USD/CAD', 'USD_CAD'),
#  ('USD/CHF', 'USD_CHF'),
#  ('USD/CNH', 'USD_CNH'),
#  ('USD/CZK', 'USD_CZK'),
#  ('USD/DKK', 'USD_DKK'),
#  ('USD/HKD', 'USD_HKD'),
#  ('USD/HUF', 'USD_HUF'),
#  ('USD/JPY', 'USD_JPY'),
#  ('USD/MXN', 'USD_MXN'),
#  ('USD/NOK', 'USD_NOK'),
#  ('USD/PLN', 'USD_PLN'),
#  ('USD/SEK', 'USD_SEK'),
#  ('USD/SGD', 'USD_SGD'),
#  ('USD/THB', 'USD_THB'),
#  ('USD/TRY', 'USD_TRY'),
#  ('USD/ZAR', 'USD_ZAR'),
#  ('West Texas Oil', 'WTICO_USD'),
#  ('Wheat', 'WHEAT_USD'),
#  ('ZAR/JPY', 'ZAR_JPY')]

# %%
api.get_history("SPX500_USD", "2020-08-03", "2020-08-04", "H1", "A")
# Out:
#                           o       h       l       c  volume  complete
# time
# 2020-08-03 00:00:00  3272.8  3276.1  3267.0  3273.5    2094      True
# 2020-08-03 01:00:00  3273.8  3279.6  3271.5  3277.8    1916      True
# 2020-08-03 02:00:00  3278.1  3278.1  3270.5  3271.8     843      True
# 2020-08-03 03:00:00  3272.3  3273.8  3269.5  3270.3     482      True
# 2020-08-03 04:00:00  3270.6  3271.8  3268.5  3271.8     368      True
# 2020-08-03 05:00:00  3272.0  3275.6  3270.0  3272.4     499      True
# 2020-08-03 06:00:00  3272.0  3272.8  3267.3  3270.0     743      True
# 2020-08-03 07:00:00  3270.3  3272.3  3263.0  3272.0    1717      True
# 2020-08-03 08:00:00  3272.3  3275.9  3264.3  3267.8    1160      True
# 2020-08-03 09:00:00  3267.5  3275.3  3266.0  3275.0    1085      True
# 2020-08-03 10:00:00  3274.5  3288.8  3273.8  3288.0    1078      True
# 2020-08-03 11:00:00  3288.3  3292.0  3286.2  3291.8     697      True
# 2020-08-03 12:00:00  3292.3  3294.1  3290.3  3292.5     596      True
# 2020-08-03 13:00:00  3292.6  3293.3  3284.7  3291.0    1555      True
# 2020-08-03 14:00:00  3290.8  3300.0  3286.5  3289.7    1824      True
# 2020-08-03 15:00:00  3290.0  3301.5  3289.2  3298.2     753      True
# 2020-08-03 16:00:00  3298.5  3299.5  3295.0  3296.5     633      True
# 2020-08-03 17:00:00  3297.0  3300.0  3296.2  3298.5     566      True
# 2020-08-03 18:00:00  3298.8  3303.5  3296.7  3302.2     845      True
# 2020-08-03 19:00:00  3302.5  3303.1  3291.5  3295.2    1796      True
# 2020-08-03 20:00:00  3295.0  3298.6  3291.2  3297.0     643      True
# 2020-08-03 22:00:00  3295.8  3296.6  3293.8  3295.3     478      True
# 2020-08-03 23:00:00  3295.0  3298.4  3294.3  3295.8     409      True

# %% [markdown]
# ## Streaming high-frequency real-time Data
# * Ideal for alpha algorithms to identify market manipulation

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
api.stream_data('EUR_USD', stop = 10)
# Out:
# 2024-09-10T04:27:03.203127852Z 1.10367 1.10377
# 2024-09-10T04:27:53.895989576Z 1.10368 1.10377
# 2024-09-10T04:27:54.200834386Z 1.10367 1.10377
# 2024-09-10T04:27:54.545315428Z 1.10368 1.10377
# 2024-09-10T04:27:54.764415734Z 1.10367 1.10377
# 2024-09-10T04:27:59.289294653Z 1.10368 1.10377
# 2024-09-10T04:27:59.831518901Z 1.10367 1.10377
# 2024-09-10T04:28:17.374065378Z 1.10368 1.10377
# 2024-09-10T04:28:17.768969622Z 1.10367 1.10377
# 2024-09-10T04:28:49.296252158Z 1.10363 1.10373

# %%
#api.stop_stream()

# %%
api.get_instruments()
# Out:
# [('AUD/CAD', 'AUD_CAD'),
#  ('AUD/CHF', 'AUD_CHF'),
#  ('AUD/HKD', 'AUD_HKD'),
#  ('AUD/JPY', 'AUD_JPY'),
#  ('AUD/NZD', 'AUD_NZD'),
#  ('AUD/SGD', 'AUD_SGD'),
#  ('AUD/USD', 'AUD_USD'),
#  ('Australia 200', 'AU200_AUD'),
#  ('Bitcoin', 'BTC_USD'),
#  ('Bitcoin Cash', 'BCH_USD'),
#  ('Brent Crude Oil', 'BCO_USD'),
#  ('Bund', 'DE10YB_EUR'),
#  ('CAD/CHF', 'CAD_CHF'),
#  ('CAD/HKD', 'CAD_HKD'),
#  ('CAD/JPY', 'CAD_JPY'),
#  ('CAD/SGD', 'CAD_SGD'),
#  ('CHF/HKD', 'CHF_HKD'),
#  ('CHF/JPY', 'CHF_JPY'),
#  ('CHF/ZAR', 'CHF_ZAR'),
#  ('China A50', 'CN50_USD'),
#  ('China H Shares', 'CHINAH_HKD'),
#  ('Copper', 'XCU_USD'),
#  ('Corn', 'CORN_USD'),
#  ('EUR/AUD', 'EUR_AUD'),
#  ('EUR/CAD', 'EUR_CAD'),
#  ('EUR/CHF', 'EUR_CHF'),
#  ('EUR/CZK', 'EUR_CZK'),
#  ('EUR/DKK', 'EUR_DKK'),
#  ('EUR/GBP', 'EUR_GBP'),
#  ('EUR/HKD', 'EUR_HKD'),
#  ('EUR/HUF', 'EUR_HUF'),
#  ('EUR/JPY', 'EUR_JPY'),
#  ('EUR/NOK', 'EUR_NOK'),
#  ('EUR/NZD', 'EUR_NZD'),
#  ('EUR/PLN', 'EUR_PLN'),
#  ('EUR/SEK', 'EUR_SEK'),
#  ('EUR/SGD', 'EUR_SGD'),
#  ('EUR/TRY', 'EUR_TRY'),
#  ('EUR/USD', 'EUR_USD'),
#  ('EUR/ZAR', 'EUR_ZAR'),
#  ('Ether', 'ETH_USD'),
#  ('Europe 50', 'EU50_EUR'),
#  ('France 40', 'FR40_EUR'),
#  ('GBP/AUD', 'GBP_AUD'),
#  ('GBP/CAD', 'GBP_CAD'),
#  ('GBP/CHF', 'GBP_CHF'),
#  ('GBP/HKD', 'GBP_HKD'),
#  ('GBP/JPY', 'GBP_JPY'),
#  ('GBP/NZD', 'GBP_NZD'),
#  ('GBP/PLN', 'GBP_PLN'),
#  ('GBP/SGD', 'GBP_SGD'),
#  ('GBP/USD', 'GBP_USD'),
#  ('GBP/ZAR', 'GBP_ZAR'),
#  ('Germany 30', 'DE30_EUR'),
#  ('Gold', 'XAU_USD'),
#  ('Gold/AUD', 'XAU_AUD'),
#  ('Gold/CAD', 'XAU_CAD'),
#  ('Gold/CHF', 'XAU_CHF'),
#  ('Gold/EUR', 'XAU_EUR'),
#  ('Gold/GBP', 'XAU_GBP'),
#  ('Gold/HKD', 'XAU_HKD'),
#  ('Gold/JPY', 'XAU_JPY'),
#  ('Gold/NZD', 'XAU_NZD'),
#  ('Gold/SGD', 'XAU_SGD'),
#  ('Gold/Silver', 'XAU_XAG'),
#  ('HKD/JPY', 'HKD_JPY'),
#  ('Hong Kong 33', 'HK33_HKD'),
#  ('Japan 225', 'JP225_USD'),
#  ('Japan 225 (JPY)', 'JP225Y_JPY'),
#  ('Litecoin', 'LTC_USD'),
#  ('NZD/CAD', 'NZD_CAD'),
#  ('NZD/CHF', 'NZD_CHF'),
#  ('NZD/HKD', 'NZD_HKD'),
#  ('NZD/JPY', 'NZD_JPY'),
#  ('NZD/SGD', 'NZD_SGD'),
#  ('NZD/USD', 'NZD_USD'),
#  ('Natural Gas', 'NATGAS_USD'),
#  ('Netherlands 25', 'NL25_EUR'),
#  ('Palladium', 'XPD_USD'),
#  ('Platinum', 'XPT_USD'),
#  ('SGD/CHF', 'SGD_CHF'),
#  ('SGD/JPY', 'SGD_JPY'),
#  ('Silver', 'XAG_USD'),
#  ('Silver/AUD', 'XAG_AUD'),
#  ('Silver/CAD', 'XAG_CAD'),
#  ('Silver/CHF', 'XAG_CHF'),
#  ('Silver/EUR', 'XAG_EUR'),
#  ('Silver/GBP', 'XAG_GBP'),
#  ('Silver/HKD', 'XAG_HKD'),
#  ('Silver/JPY', 'XAG_JPY'),
#  ('Silver/NZD', 'XAG_NZD'),
#  ('Silver/SGD', 'XAG_SGD'),
#  ('Singapore 30', 'SG30_SGD'),
#  ('Soybeans', 'SOYBN_USD'),
#  ('Spain 35', 'ESPIX_EUR'),
#  ('Sugar', 'SUGAR_USD'),
#  ('Switzerland 20', 'CH20_CHF'),
#  ('TRY/JPY', 'TRY_JPY'),
#  ('UK 100', 'UK100_GBP'),
#  ('UK 10Y Gilt', 'UK10YB_GBP'),
#  ('US 10Y T-Note', 'USB10Y_USD'),
#  ('US 2Y T-Note', 'USB02Y_USD'),
#  ('US 5Y T-Note', 'USB05Y_USD'),
#  ('US Nas 100', 'NAS100_USD'),
#  ('US Russ 2000', 'US2000_USD'),
#  ('US SPX 500', 'SPX500_USD'),
#  ('US T-Bond', 'USB30Y_USD'),
#  ('US Wall St 30', 'US30_USD'),
#  ('USD/CAD', 'USD_CAD'),
#  ('USD/CHF', 'USD_CHF'),
#  ('USD/CNH', 'USD_CNH'),
#  ('USD/CZK', 'USD_CZK'),
#  ('USD/DKK', 'USD_DKK'),
#  ('USD/HKD', 'USD_HKD'),
#  ('USD/HUF', 'USD_HUF'),
#  ('USD/JPY', 'USD_JPY'),
#  ('USD/MXN', 'USD_MXN'),
#  ('USD/NOK', 'USD_NOK'),
#  ('USD/PLN', 'USD_PLN'),
#  ('USD/SEK', 'USD_SEK'),
#  ('USD/SGD', 'USD_SGD'),
#  ('USD/THB', 'USD_THB'),
#  ('USD/TRY', 'USD_TRY'),
#  ('USD/ZAR', 'USD_ZAR'),
#  ('West Texas Oil', 'WTICO_USD'),
#  ('Wheat', 'WHEAT_USD'),
#  ('ZAR/JPY', 'ZAR_JPY')]

# %%
api.stream_data('AUD_CAD')
# Out:
# 2024-09-10T04:30:18.423057758Z 0.9036 0.90375
# 2024-09-10T04:30:36.593716459Z 0.90355 0.9037
# 2024-09-10T04:30:43.391971052Z 0.90358 0.90372
# 2024-09-10T04:30:43.624292851Z 0.90356 0.90372
# 2024-09-10T04:30:44.137995721Z 0.90357 0.90372
# 2024-09-10T04:30:44.653953702Z 0.90356 0.90372
# 2024-09-10T04:30:45.445442609Z 0.90358 0.90372
# 2024-09-10T04:30:48.598342984Z 0.90356 0.90372
# 2024-09-10T04:30:49.064403776Z 0.90357 0.90372
# 2024-09-10T04:30:50.163480782Z 0.90359 0.90373
# 2024-09-10T04:30:51.442455862Z 0.90357 0.90373
# 2024-09-10T04:30:53.848684323Z 0.90358 0.90373
# 2024-09-10T04:30:54.006489917Z 0.90359 0.90373
# 2024-09-10T04:30:54.275593939Z 0.90357 0.90373
# 2024-09-10T04:30:57.623967088Z 0.90357 0.90374
# 2024-09-10T04:31:00.268381805Z 0.90357 0.90372
# 2024-09-10T04:31:01.970886345Z 0.90356 0.90372
# 2024-09-10T04:31:02.911776174Z 0.90356 0.90372
# 2024-09-10T04:31:04.704531347Z 0.90357 0.90372
# 2024-09-10T04:31:07.064613778Z 0.90358 0.90375
# 2024-09-10T04:31:14.843614364Z 0.90358 0.90374
# 2024-09-10T04:31:15.068301160Z 0.90358 0.90373
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 api.stream_data('AUD_CAD')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\tpqoa-0.0.56-py3.12.egg\tpqoa\tpqoa.py:346, in tpqoa.stream_data(self, instrument, stop, ret, callback)
#     342 response = self.ctx_stream.pricing.stream(
#     343     self.account_id, snapshot=True,
#     344     instruments=instrument)
#     345 msgs = []
# --> 346 for msg_type, msg in response.parts():
#     347     msgs.append(msg)
#     348     # print(msg_type, msg)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\v20\response.py:52, in Response.parts(self)
#      49     return
#      51 try:
# ---> 52     for line in self.lines:
#      53         yield parser(line)
#      54 except requests.exceptions.ConnectionError:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\models.py:869, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     860 """Iterates over the response data, one line at a time.  When
#     861 stream=True is set on the request, this avoids reading the
#     862 content at once into memory for large responses.
#     863
#     864 .. note:: This method is not reentrant safe.
#     865 """
#     867 pending = None
# --> 869 for chunk in self.iter_content(
#     870     chunk_size=chunk_size, decode_unicode=decode_unicode
#     871 ):
#     872     if pending is not None:
#     873         chunk = pending + chunk
#
# File C:\ProgramData\anaconda3\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\response.py:1057, in HTTPResponse.stream(self, amt, decode_content)
#    1041 """
#    1042 A generator wrapper for the read() method. A call will block until
#    1043 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1054     'content-encoding' header.
#    1055 """
#    1056 if self.chunked and self.supports_chunked_reads():
# -> 1057     yield from self.read_chunked(amt, decode_content=decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\response.py:1206, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1203     amt = None
#    1205 while True:
# -> 1206     self._update_chunk_length()
#    1207     if self.chunk_left == 0:
#    1208         break
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\response.py:1125, in HTTPResponse._update_chunk_length(self)
#    1123 if self.chunk_left is not None:
#    1124     return None
# -> 1125 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1126 line = line.split(b";", 1)[0]
#    1127 try:
#
# File C:\ProgramData\anaconda3\Lib\socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File C:\ProgramData\anaconda3\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File C:\ProgramData\anaconda3\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Creating Orders and Executing Trades

# %%
import pandas as pd
import tpqoa

# %%
api = tpqoa.tpqoa("oanda.cfg")

# %%
api.create_order(instrument = "EUR_USD", units = 100000, sl_distance= 0.1)
# Out:
#  {'id': '11', 'time': '2024-09-10T04:34:21.198805800Z', 'userID': 29824769, 'accountID': '101-011-29824769-001', 'batchID': '10', 'requestID': '61282324576054030', 'type': 'ORDER_FILL', 'orderID': '10', 'instrument': 'EUR_USD', 'units': '100000.0', 'gainQuoteHomeConversionFactor': '1.493623970956', 'lossQuoteHomeConversionFactor': '1.508635267147', 'price': 1.10385, 'fullVWAP': 1.10385, 'fullPrice': {'type': 'PRICE', 'bids': [{'price': 1.10376, 'liquidity': '500000'}, {'price': 1.10375, 'liquidity': '2500000'}, {'price': 1.10374, 'liquidity': '2000000'}, {'price': 1.10373, 'liquidity': '5000000'}, {'price': 1.1037, 'liquidity': '10000000'}, {'price': 1.10367, 'liquidity': '10000000'}], 'asks': [{'price': 1.10385, 'liquidity': '500000'}, {'price': 1.10386, 'liquidity': '500000'}, {'price': 1.10387, 'liquidity': '2000000'}, {'price': 1.10388, 'liquidity': '2000000'}, {'price': 1.10389, 'liquidity': '5000000'}, {'price': 1.10391, 'liquidity': '10000000'}, {'price': 1.10394, 'liquidity': '10000000'}], 'closeoutBid': 1.10367, 'closeoutAsk': 1.10394}, 'reason': 'MARKET_ORDER', 'pl': '0.0', 'financing': '0.0', 'commission': '0.0', 'guaranteedExecutionFee': '0.0', 'accountBalance': '99993.7785', 'tradeOpened': {'tradeID': '11', 'units': '100000.0', 'price': 1.10385, 'guaranteedExecutionFee': '0.0', 'halfSpreadCost': '6.7551', 'initialMarginRequired': '5517.7767'}, 'halfSpreadCost': '6.7551'}

# %%
api.create_order(instrument = "EUR_USD", units = 100000, sl_distance= 0.1)
# Out:
#  {'id': '20', 'time': '2024-09-10T04:40:07.089064742Z', 'userID': 29824769, 'accountID': '101-011-29824769-001', 'batchID': '19', 'requestID': '61282326027561372', 'type': 'ORDER_FILL', 'orderID': '19', 'instrument': 'EUR_USD', 'units': '100000.0', 'gainQuoteHomeConversionFactor': '1.493635179216', 'lossQuoteHomeConversionFactor': '1.508646588052', 'price': 1.10391, 'fullVWAP': 1.10391, 'fullPrice': {'type': 'PRICE', 'bids': [{'price': 1.10381, 'liquidity': '500000'}, {'price': 1.1038, 'liquidity': '2500000'}, {'price': 1.10379, 'liquidity': '2000000'}, {'price': 1.10378, 'liquidity': '5000000'}, {'price': 1.10375, 'liquidity': '10000000'}, {'price': 1.10372, 'liquidity': '10000000'}], 'asks': [{'price': 1.10391, 'liquidity': '500000'}, {'price': 1.10392, 'liquidity': '500000'}, {'price': 1.10393, 'liquidity': '2000000'}, {'price': 1.10394, 'liquidity': '2000000'}, {'price': 1.10395, 'liquidity': '5000000'}, {'price': 1.10397, 'liquidity': '10000000'}, {'price': 1.104, 'liquidity': '10000000'}], 'closeoutBid': 1.10372, 'closeoutAsk': 1.104}, 'reason': 'MARKET_ORDER', 'pl': '-19.6124', 'financing': '0.0', 'commission': '0.0', 'guaranteedExecutionFee': '0.0', 'accountBalance': '99963.605', 'tradesClosed': [{'tradeID': '17', 'units': '100000.0', 'price': 1.10391, 'realizedPL': '-19.6124', 'financing': '0.0', 'guaranteedExecutionFee': '0.0', 'halfSpreadCost': '7.5057'}], 'halfSpreadCost': '7.5057'}

# %%
api.get_account_summary()
# Out:
# {'id': '101-011-29824769-001',
#  'alias': 'Primary',
#  'currency': 'AUD',
#  'balance': '99963.605',
#  'createdByUserID': 29824769,
#  'createdTime': '2024-09-02T22:42:48.601781899Z',
#  'guaranteedStopLossOrderMode': 'ALLOWED',
#  'pl': '-36.395',
#  'resettablePL': '-36.395',
#  'resettablePLTime': '0',
#  'financing': '0.0',
#  'commission': '0.0',
#  'guaranteedExecutionFees': '0.0',
#  'marginRate': '0.02',
#  'openTradeCount': 0,
#  'openPositionCount': 0,
#  'pendingOrderCount': 0,
#  'hedgingEnabled': False,
#  'unrealizedPL': '0.0',
#  'NAV': '99963.605',
#  'marginUsed': '0.0',
#  'marginAvailable': '99963.605',
#  'positionValue': '0.0',
#  'marginCloseoutUnrealizedPL': '0.0',
#  'marginCloseoutNAV': '99963.605',
#  'marginCloseoutMarginUsed': '0.0',
#  'marginCloseoutPercent': '0.0',
#  'marginCloseoutPositionValue': '0.0',
#  'withdrawalLimit': '99963.605',
#  'marginCallMarginUsed': '0.0',
#  'marginCallPercent': '0.0',
#  'lastTransactionID': '21'}

# %%
api.get_transactions(tid = 11)
# Out:
# [{'id': '12',
#   'time': '2024-09-10T04:34:21.198805800Z',
#   'userID': 29824769,
#   'accountID': '101-011-29824769-001',
#   'batchID': '10',
#   'requestID': '61282324576054030',
#   'type': 'STOP_LOSS_ORDER',
#   'tradeID': '11',
#   'price': 1.00385,
#   'distance': '0.1',
#   'timeInForce': 'GTC',
#   'triggerCondition': 'DEFAULT',
#   'reason': 'ON_FILL'},
#  {'id': '13',
#   'time': '2024-09-10T04:36:37.822687428Z',
#   'userID': 29824769,
#   'accountID': '101-011-29824769-001',
#   'batchID': '13',
#   'requestID': '61282325146591681',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-100000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '14',
#   'time': '2024-09-10T04:36:37.822687428Z',
#   'userID': 29824769,
#   'accountID': '101-011-29824769-001',
#   'batchID': '13',
#   'requestID': '61282325146591681',
#   'type': 'ORDER_FILL',
#   'orderID': '13',
#   'instrument': 'EUR_USD',
#   'units': '-100000.0',
#   'gainQuoteHomeConversionFactor': '1.493713656557',
#   'lossQuoteHomeConversionFactor': '1.50872585411',
#   'price': 1.10378,
#   'fullVWAP': 1.10378,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.10378, 'liquidity': '500000'},
#     {'price': 1.10377, 'liquidity': '2500000'},
#     {'price': 1.10376, 'liquidity': '2000000'},
#     {'price': 1.10375, 'liquidity': '5000000'},
#     {'price': 1.10372, 'liquidity': '10000000'},
#     {'price': 1.10369, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.10387, 'liquidity': '500000'},
#     {'price': 1.10388, 'liquidity': '500000'},
#     {'price': 1.10389, 'liquidity': '2000000'},
#     {'price': 1.1039, 'liquidity': '2000000'},
#     {'price': 1.10391, 'liquidity': '5000000'},
#     {'price': 1.10393, 'liquidity': '10000000'},
#     {'price': 1.10396, 'liquidity': '10000000'}],
#    'closeoutBid': 1.10369,
#    'closeoutAsk': 1.10396},
#   'reason': 'MARKET_ORDER',
#   'pl': '-10.5611',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99983.2174',
#   'tradesClosed': [{'tradeID': '11',
#     'units': '-100000.0',
#     'price': 1.10378,
#     'realizedPL': '-10.5611',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '6.7555'}],
#   'halfSpreadCost': '6.7555'},
#  {'id': '15',
#   'time': '2024-09-10T04:36:37.822687428Z',
#   'userID': 29824769,
#   'accountID': '101-011-29824769-001',
#   'batchID': '13',
#   'requestID': '61282325146591681',
#   'type': 'ORDER_CANCEL',
#   'orderID': '12',
#   'reason': 'LINKED_TRADE_CLOSED'},
#  {'id': '16',
#   'time': '2024-09-10T04:39:33.006814423Z',
#   'userID': 29824769,
#   'accountID': '101-011-29824769-001',
#   'batchID': '16',
#   'requestID': '79296724394853951',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '-100000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '17',
#   'time': '2024-09-10T04:39:33.006814423Z',
#   'userID': 29824769,
#   'accountID': '101-011-29824769-001',
#   'batchID': '16',
#   'requestID': '79296724394853951',
#   'type': 'ORDER_FILL',
#   'orderID': '16',
#   'instrument': 'EUR_USD',
#   'units': '-100000.0',
#   'gainQuoteHomeConversionFactor': '1.493713652518',
#   'lossQuoteHomeConversionFactor': '1.50872585003',
#   'price': 1.10378,
#   'fullVWAP': 1.10378,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.10378, 'liquidity': '500000'},
#     {'price': 1.10377, 'liquidity': '2500000'},
#     {'price': 1.10376, 'liquidity': '2000000'},
#     {'price': 1.10375, 'liquidity': '5000000'},
#     {'price': 1.10372, 'liquidity': '10000000'},
#     {'price': 1.10369, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.10388, 'liquidity': '500000'},
#     {'price': 1.10389, 'liquidity': '500000'},
#     {'price': 1.1039, 'liquidity': '2000000'},
#     {'price': 1.10391, 'liquidity': '2000000'},
#     {'price': 1.10392, 'liquidity': '5000000'},
#     {'price': 1.10394, 'liquidity': '10000000'},
#     {'price': 1.10397, 'liquidity': '10000000'}],
#    'closeoutBid': 1.10369,
#    'closeoutAsk': 1.10397},
#   'reason': 'MARKET_ORDER',
#   'pl': '0.0',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99983.2174',
#   'tradeOpened': {'tradeID': '17',
#    'units': '-100000.0',
#    'price': 1.10378,
#    'guaranteedExecutionFee': '0.0',
#    'halfSpreadCost': '7.5061',
#    'initialMarginRequired': '5518.143'},
#   'halfSpreadCost': '7.5061'},
#  {'id': '18',
#   'time': '2024-09-10T04:39:33.006814423Z',
#   'userID': 29824769,
#   'accountID': '101-011-29824769-001',
#   'batchID': '16',
#   'requestID': '79296724394853951',
#   'type': 'STOP_LOSS_ORDER',
#   'tradeID': '17',
#   'price': 1.20378,
#   'distance': '0.1',
#   'timeInForce': 'GTC',
#   'triggerCondition': 'DEFAULT',
#   'reason': 'ON_FILL'},
#  {'id': '19',
#   'time': '2024-09-10T04:40:07.089064742Z',
#   'userID': 29824769,
#   'accountID': '101-011-29824769-001',
#   'batchID': '19',
#   'requestID': '61282326027561372',
#   'type': 'MARKET_ORDER',
#   'instrument': 'EUR_USD',
#   'units': '100000.0',
#   'timeInForce': 'FOK',
#   'positionFill': 'DEFAULT',
#   'reason': 'CLIENT_ORDER',
#   'stopLossOnFill': {'distance': '0.1', 'timeInForce': 'GTC'}},
#  {'id': '20',
#   'time': '2024-09-10T04:40:07.089064742Z',
#   'userID': 29824769,
#   'accountID': '101-011-29824769-001',
#   'batchID': '19',
#   'requestID': '61282326027561372',
#   'type': 'ORDER_FILL',
#   'orderID': '19',
#   'instrument': 'EUR_USD',
#   'units': '100000.0',
#   'gainQuoteHomeConversionFactor': '1.493635179216',
#   'lossQuoteHomeConversionFactor': '1.508646588052',
#   'price': 1.10391,
#   'fullVWAP': 1.10391,
#   'fullPrice': {'type': 'PRICE',
#    'bids': [{'price': 1.10381, 'liquidity': '500000'},
#     {'price': 1.1038, 'liquidity': '2500000'},
#     {'price': 1.10379, 'liquidity': '2000000'},
#     {'price': 1.10378, 'liquidity': '5000000'},
#     {'price': 1.10375, 'liquidity': '10000000'},
#     {'price': 1.10372, 'liquidity': '10000000'}],
#    'asks': [{'price': 1.10391, 'liquidity': '500000'},
#     {'price': 1.10392, 'liquidity': '500000'},
#     {'price': 1.10393, 'liquidity': '2000000'},
#     {'price': 1.10394, 'liquidity': '2000000'},
#     {'price': 1.10395, 'liquidity': '5000000'},
#     {'price': 1.10397, 'liquidity': '10000000'},
#     {'price': 1.104, 'liquidity': '10000000'}],
#    'closeoutBid': 1.10372,
#    'closeoutAsk': 1.104},
#   'reason': 'MARKET_ORDER',
#   'pl': '-19.6124',
#   'financing': '0.0',
#   'commission': '0.0',
#   'guaranteedExecutionFee': '0.0',
#   'accountBalance': '99963.605',
#   'tradesClosed': [{'tradeID': '17',
#     'units': '100000.0',
#     'price': 1.10391,
#     'realizedPL': '-19.6124',
#     'financing': '0.0',
#     'guaranteedExecutionFee': '0.0',
#     'halfSpreadCost': '7.5057'}],
#   'halfSpreadCost': '7.5057'},
#  {'id': '21',
#   'time': '2024-09-10T04:40:07.089064742Z',
#   'userID': 29824769,
#   'accountID': '101-011-29824769-001',
#   'batchID': '19',
#   'requestID': '61282326027561372',
#   'type': 'ORDER_CANCEL',
#   'orderID': '18',
#   'reason': 'LINKED_TRADE_CLOSED'}]

# %%
api.print_transactions(tid = 20-1)
# Out:
#   20 | 2024-09-10T04:40:07.08 | EUR_USD | 100000.0 | -19.6124

# %%
api.create_order(instrument = "EUR_USD", units = 1000000, sl_distance= 0.1)
# Out:
#  {'id': '23', 'time': '2024-09-10T04:44:10.809163870Z', 'userID': 29824769, 'accountID': '101-011-29824769-001', 'batchID': '22', 'requestID': '97311124063629369', 'type': 'ORDER_FILL', 'orderID': '22', 'instrument': 'EUR_USD', 'units': '1000000.0', 'gainQuoteHomeConversionFactor': '1.493175676194', 'lossQuoteHomeConversionFactor': '1.50818246691', 'price': 1.10404, 'fullVWAP': 1.10404, 'fullPrice': {'type': 'PRICE', 'bids': [{'price': 1.10394, 'liquidity': '500000'}, {'price': 1.10393, 'liquidity': '2500000'}, {'price': 1.10392, 'liquidity': '2000000'}, {'price': 1.10391, 'liquidity': '5000000'}, {'price': 1.10388, 'liquidity': '10000000'}, {'price': 1.10385, 'liquidity': '10000000'}], 'asks': [{'price': 1.10404, 'liquidity': '500000'}, {'price': 1.10405, 'liquidity': '500000'}, {'price': 1.10406, 'liquidity': '2000000'}, {'price': 1.10407, 'liquidity': '2000000'}, {'price': 1.10408, 'liquidity': '5000000'}, {'price': 1.1041, 'liquidity': '10000000'}, {'price': 1.10413, 'liquidity': '10000000'}], 'closeoutBid': 1.10385, 'closeoutAsk': 1.10413}, 'reason': 'MARKET_ORDER', 'pl': '0.0', 'financing': '0.0', 'commission': '0.0', 'guaranteedExecutionFee': '0.0', 'accountBalance': '99963.605', 'tradeOpened': {'tradeID': '23', 'units': '1000000.0', 'price': 1.10404, 'guaranteedExecutionFee': '0.0', 'halfSpreadCost': '75.034', 'initialMarginRequired': '55169.109'}, 'halfSpreadCost': '75.034'}

# %%
## Transactions
